# %% [markdown]
# <a href="https://colab.research.google.com/github/abs-sharma/pyscript-gp/blob/main/data-structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
f = np.linspace(4,0)
#linspace

# %%
import math
math.exp(3)
# Out:
# 20.085536923187668

# %%
math.sqrt(8)
# Out:
# 2.8284271247461903

# %%
import random
random.sample([8,9,0,0,9,0],4)
# Out:
# [9, 8, 0, 0]

# %%
#compound interest
principal = float(input("principal:"))
interest = float(input("interest:"))
time = float(input("time:"))
total = principal * math.pow(1+(interest/100),time)
print(total-principal)
# Out:
# principal:780
# interest:5.90
# time:8
# 453.8497673905474

# %%
eo = lambda x:"odd" if (x/2) else "even"
eo(9)
# Out:
# 'odd'

# %%
def sq(x):
  return x*x
r = [9,0,8,9]
set(map(sq,r))
# Out:
# {0, 64, 81}

# %%
list(map(lambda x:x*x,r))
# Out:
# [81, 0, 64, 81]

# %%
t=[0,1,2,3]
w=[9,7,4,5]
list(map(lambda x,y:x-y,t,w))
# Out:
# [-9, -6, -2, -2]

# %%
def er(i):
  if i%2 :
    return i
dd= [0,3,2,1,4]
list(filter(er,dd))
# Out:
# [3, 1]

# %%
list(filter(lambda x:x%2,dd))
# Out:
# [3, 1]

# %%
wed = [4,5,5,6,10,6,0,8,77,4]
